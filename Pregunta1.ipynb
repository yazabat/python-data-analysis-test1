# 175059  2017-02-18 04:27:43 2017-02-18 10:27:43 0 days 06:00:00
# 1070503 2019-10-06 04:08:00 2019-10-06 04:40:30 0 days 00:32:30
# 217647  2017-06-19 14:25:07 2017-06-19 20:25:07 0 days 06:00:00
# 172942  2017-02-13 17:57:43 2017-02-13 23:57:43 0 days 06:00:00
# 555645  2020-11-23 03:51:00 2020-11-23 05:06:00 0 days 01:15:00
# 104177  2016-04-04 07:11:45 2016-04-04 13:11:45 0 days 06:00:00
# 1199464 2019-01-08 14:34:50 2019-01-08 15:04:27 0 days 00:29:37
# 1173892 2019-03-28 21:10:42 2019-03-28 21:38:05 0 days 00:27:23
# 485634  2020-12-14 14:49:00 2020-12-14 20:05:36 0 days 05:16:36
# 769609  2020-05-14 17:11:04 2020-05-14 18:11:04 0 days 01:00:00
# 141487  2016-07-18 16:16:48 2016-07-18 22:16:48 0 days 06:00:00
# 1435421 2017-08-17 01:57:10 2017-08-17 07:57:10 0 days 06:00:00
# 439869  2020-11-05 02:34:00 2020-11-05 04:40:23 0 days 02:06:23
# 174492  2017-02-16 14:41:45 2017-02-16 20:41:45 0 days 06:00:00

# %%
str(acci.DeltaT[0])[7:]
# Out:
# '06:00:00'

# %%
deltattype = acci.dtypes["DeltaT"]
deltattype


acci.DeltaT.sample(10)

acci.DeltaT=acci.DeltaT.dt.seconds/(60*60)
acci.DeltaT.sample(10)
# Out:
# 1124557    0.468056
# 89393      6.000000
# 1293267    4.000000
# 1263594    0.495278
# 665544     2.000000
# 221809     6.000000
# 1278788    4.000000
# 294039     5.189167
# 1158807    4.000000
# 562570     1.425000
# Name: DeltaT, dtype: float64

# %%
# ==============================================================
#  Construya las columnas que almacenen la información de
#  Año, mes, dia y hora.
# ==============================================================
#Nuevas columnas para Start_Time
acci["Start_Time_YEAR"] = acci["Start_Time"].dt.year
acci["Start_Time_MONTH"] = acci["Start_Time"].dt.month
acci["Start_Time_DAY"] = acci["Start_Time"].dt.day
acci["Start_Time_HOUR"] = acci["Start_Time"].dt.strftime("%H:%M:%S")

acci[["Start_Time_YEAR","Start_Time_MONTH","Start_Time_HOUR"]].sample(n=10)

#Nuevas columnas para End_Time
acci["End_Time_YEAR"] = acci["End_Time"].dt.year
acci["End_Time_MONTH"] = acci["End_Time"].dt.month
acci["End_Time_DAY"] = acci["End_Time"].dt.day
acci["End_Time_HOUR"] = acci["End_Time"].dt.strftime("%H:%M:%S")

acci[['Start_Time_HOUR', 'End_Time_HOUR']].sample(n=10)
# Out:
#         Start_Time_HOUR End_Time_HOUR
# 576240         23:25:37      01:25:37
# 1480461        16:44:13      17:14:12
# 1267819        11:30:46      12:00:07
# 753011         15:28:39      15:58:39
# 1169772        10:32:07      14:32:07
# 740702         16:49:54      18:04:54
# 1266838        06:50:29      07:20:25
# 581064         02:57:00      04:12:18
# 401171         12:59:30      02:41:55
# 1114173        23:24:00      00:18:25

# %%
dir(acci.State)
tenStates=acci.State.value_counts().head(10)
tenStates.index

# Nuevo dataframe para hacer el analisis descriptivo

accTenST=acci[acci.State.isin(tenStates.index)]
accTenST

import numpy as np
np.unique(accTenST.State)

import seaborn as sns
sns.barplot(data=accTenST, x="Distance(mi)", y="State")
# Out:
# <AxesSubplot:xlabel='Distance(mi)', ylabel='State'>

# %%
import seaborn as sns
dir(acci.Timezone)
acci.Timezone.unique()
acci.Severity.unique()

grouped=acci.groupby(['Timezone','Severity']).size()
grouped_df=grouped.to_frame()
gb_pivot=grouped_df.pivot_table(index='Timezone', columns='Severity')
gb_pivot.plot.bar(figsize=(18 ,6))
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-6ac1aa70e2b2> in <module>
#       8 gb_pivot=grouped_df.pivot_table(index='Timezone', columns='Severity')
#       9 gb_pivot.plot.bar(figsize=(18 ,6))
# ---> 10 plot.show()
#
# NameError: name 'plot' is not defined

# %%
from matplotlib import pyplot as plt
import seaborn as sns
dir(acci.Timezone)
acci.Timezone.unique()
acci.Severity.unique()

grouped=acci.groupby(['Timezone','Severity']).size()
grouped_df=grouped.to_frame()
gb_pivot=grouped_df.pivot_table(index='Timezone', columns='Severity')
gb_pivot.plot.bar(figsize=(18 ,6))
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\LighthouseLLC\Desktop\Econ\_UNI_Python\data\data\Pregunta1.py in <module>
#       9 gb_pivot=grouped_df.pivot_table(index='Timezone', columns='Severity')
#      10 gb_pivot.plot.bar(figsize=(18 ,6))
# ---> 11 plot.show()
#
# NameError: name 'plot' is not defined

# %%
acci[['Start_Time_HOUR', 'End_Time_HOUR']].sample(n=10)
# Out:
#         Start_Time_HOUR End_Time_HOUR
# 810537         13:09:26      14:29:24
# 1008308        17:09:00      17:45:47
# 1510615        19:39:33      20:08:48
# 863305         18:07:37      18:22:37
# 756817         13:39:59      13:54:59
# 1201619        08:41:00      10:00:00
# 70931          11:12:01      17:12:01
# 1470521        11:07:45      11:37:39
# 939283         09:44:59      11:04:57
# 608823         16:24:00      18:19:35

# %%
acci.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight', 'DeltaT', 'Start_Time_YEAR',
#        'Start_Time_MONTH', 'Start_Time_DAY', 'Start_Time_HOUR',
#        'End_Time_YEAR', 'End_Time_MONTH', 'End_Time_DAY', 'End_Time_HOUR'],
#       dtype='object')

# %%
acci[['Start_Time_YEAR', 'Temperature(F)', 'Wind_Chill(F)',
       'Humidity(%)', 'Pressure(in)']].sample(n=10)
# Out:
#          Start_Time_YEAR  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# 135943              2016            68.0           68.0         73.0
# 592548              2020            63.0           63.0         28.0
# 837767              2020            84.0           84.0         34.0
# 12562               2016            46.0           39.6         38.0
# 277227              2020            57.0           57.0         82.0
# 828416              2020            87.0           87.0          7.0
# 406461              2020            55.0           55.0         88.0
# 1206166             2019            34.0           24.2         92.0
# 296808              2020            68.0           68.0         87.0
# 1461734             2019            79.0           79.0         17.0
#
#          Pressure(in)
# 135943          29.13
# 592548          29.72
# 837767          29.15
# 12562           29.58
# 277227          29.45
# 828416          26.75
# 406461          27.22
# 1206166         29.80
# 296808          28.76
# 1461734         24.62

# %%
#Obteniendo un sample para el analidad descriptivo por anio de las 4 variables buscadas
acci[['Start_Time_YEAR', 'Temperature(F)', 'Wind_Chill(F)',
       'Humidity(%)', 'Pressure(in)']].sample(n=10)
# Out:
#          Start_Time_YEAR  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# 829820              2020            76.0           76.0         44.0
# 1209833             2019            55.4            NaN         47.0
# 495062              2020            97.0           97.0         17.0
# 1009706             2020            57.0           57.0         59.0
# 746538              2020            63.0           63.0         52.0
# 724259              2020            72.0           72.0         78.0
# 1510429             2019            87.0           87.0         48.0
# 191196              2017            68.0            NaN         47.0
# 1316444             2018            41.0            NaN         81.0
# 106432              2016            68.0            NaN         40.0
#
#          Pressure(in)
# 829820          29.45
# 1209833         30.14
# 495062          29.78
# 1009706         29.78
# 746538          29.64
# 724259          29.02
# 1510429         29.56
# 191196          29.48
# 1316444         30.29
# 106432          29.96

# %%
acci_4varperyear=acci[['Start_Time_YEAR', 'Temperature(F)', 'Wind_Chill(F)',
       'Humidity(%)', 'Pressure(in)']].sample(n=10)
gb_4varperyear=acci_4varperyear.groupby(['Start_Time_YEAR'])['Temperature(F)', 'Wind_Chill(F)','Humidity(%)', 'Pressure(in)'].mean()
# Out:
# <ipython-input-32-4fd773a7908b>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   gb_4varperyear=acci_4varperyear.groupby(['Start_Time_YEAR'])['Temperature(F)', 'Wind_Chill(F)','Humidity(%)', 'Pressure(in)'].mean()

# %%
gb_4varperyear
# Out:
#                  Temperature(F)  Wind_Chill(F)  Humidity(%)  Pressure(in)
# Start_Time_YEAR
# 2016                      79.00            NaN         23.0       29.8000
# 2017                      77.25            NaN         70.0       29.9750
# 2018                      32.00          19.80         92.0       29.7200
# 2019                      62.05          64.00         79.0       29.9300
# 2020                      50.25          46.25         63.5       29.5775

# %%
gb_4varperyear.plot.bar(figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='Start_Time_YEAR'>

# %%
#Analisis descriptivo por anio de las variables Temperature, Wind_Chill, Humidity , Pressure and visibility
gb_4varperyear.plot.bar(figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='Start_Time_YEAR'>

# %%
# %%
#Analisis descriptivo por timezone de las variables:
# - Temperature
# - Windchill
# - Humidity
# - Pressure and visibility
# %%
# Timezone vs 4 variables
acci_timezone_4var=acci[['Timezone', 'Temperature(F)', 'Wind_Chill(F)',
       'Humidity(%)', 'Pressure(in)']]
gb_acci_timezone_4var=acci_timezone_4var.groupby(['Timezone'])['Temperature(F)', 'Wind_Chill(F)','Humidity(%)', 'Pressure(in)'].mean()
gb_acci_timezone_4var.plot.bar(figsize=(18,6))
# Out:
# <ipython-input-42-c4f5d573a103>:11: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   gb_acci_timezone_4var=acci_timezone_4var.groupby(['Timezone'])['Temperature(F)', 'Wind_Chill(F)','Humidity(%)', 'Pressure(in)'].mean()
# <AxesSubplot:xlabel='Timezone'>

# %%
#Diagrama descriptivo de precipitation vs. Severity:
sever_preci=acci[['Severity','Precipitation(in)']].sample(n=10)
gb_sever_preci=sever_preci.groupby(['Severity'])['Precipitation(in)'].mean()
gb_sever_preci.plot.bar(figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='Severity'>

# %%
#Diagrama descriptivo de WC vs Cantidad de accidentes, severidad, mes
len(acci.Weather_Condition.unique())

FiveClimaCond=acci.Weather_Condition.value_counts().head(5)
accFiveWC=acci[acci.Weather_Condition.isin(FiveClimaCond.index)]
accFiveWC
accFiveWC=accFiveWC[['Weather_Condition','Severity','End_Time_MONTH']]
accFiveWC
# Out:
#         Weather_Condition  Severity  End_Time_MONTH
# 8           Mostly Cloudy         2               2
# 16          Mostly Cloudy         3               2
# 17          Mostly Cloudy         3               2
# 27                 Cloudy         2               2
# 58          Mostly Cloudy         2               2
# ...                   ...       ...             ...
# 1516059              Fair         2               8
# 1516060              Fair         2               8
# 1516061     Partly Cloudy         2               8
# 1516062              Fair         2               8
# 1516063              Fair         2               8
#
# [1133463 rows x 3 columns]

# %%
#Diagrama descriptivo de WC vs Cantidad de accidentes, y mes segun severidad
len(acci.Weather_Condition.unique())

FiveClimaCond=acci.Weather_Condition.value_counts().head(5)
accFiveWC=acci[acci.Weather_Condition.isin(FiveClimaCond.index)]
accFiveWC
# Out:
#                 ID  Severity          Start_Time            End_Time  \
# 8        A-2716608         2 2016-02-08 08:15:41 2016-02-08 14:15:41
# 16       A-2716616         3 2016-02-08 18:11:11 2016-02-09 00:11:11
# 17       A-2716617         3 2016-02-08 18:11:11 2016-02-09 00:11:11
# 27       A-2716627         2 2016-02-09 07:18:10 2016-02-09 13:18:10
# 58       A-2716658         2 2016-02-10 09:06:09 2016-02-10 15:06:09
# ...            ...       ...                 ...                 ...
# 1516059  A-4239402         2 2019-08-23 18:03:25 2019-08-23 18:32:01
# 1516060  A-4239403         2 2019-08-23 19:11:30 2019-08-23 19:38:23
# 1516061  A-4239404         2 2019-08-23 19:00:21 2019-08-23 19:28:49
# 1516062  A-4239405         2 2019-08-23 19:00:21 2019-08-23 19:29:42
# 1516063  A-4239406         2 2019-08-23 18:52:06 2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 8        39.775650  -84.186030  39.772750  -84.188050         0.227
# 16       40.151785  -81.312635  40.151747  -81.312682         0.004
# 17       40.151747  -81.312682  40.151785  -81.312635         0.004
# 27       39.307320  -85.959820  39.304570  -85.962840         0.249
# 58       38.178100  -85.719460  38.181040  -85.721160         0.223
# ...            ...         ...        ...         ...           ...
# 1516059  34.002480 -117.379360  33.998880 -117.370940         0.543
# 1516060  32.766960 -117.148060  32.765550 -117.153630         0.338
# 1516061  33.775450 -117.847790  33.777400 -117.857270         0.561
# 1516062  33.992460 -118.403020  33.983110 -118.395650         0.772
# 1516063  34.133930 -117.230920  34.137360 -117.239340         0.537
#
#                                                Description  ...  \
# 8                              At OH-4/Exit 54 - Accident.  ...
# 16                               At Shipley Rd - Accident.  ...
# 17                                 At Titus Rd - Accident.  ...
# 27                            At US-31/Exit 76 - Accident.  ...
# 58                At KY-61/Grade Lane/Exit 130 - Accident.  ...
# ...                                                    ...  ...
# 1516059                           At Market St - Accident.  ...
# 1516060    At Camino Del Rio/Mission Center Rd - Accident.  ...
# 1516061  At Glassell St/Grand Ave - Accident. in the ri...  ...
# 1516062     At CA-90/Marina Fwy/Jefferson Blvd - Accident.  ...
# 1516063              At Highland Ave/Arden Ave - Accident.  ...
#
#          Astronomical_Twilight    DeltaT Start_Time_YEAR Start_Time_MONTH  \
# 8                          Day  6.000000            2016                2
# 16                         Day  6.000000            2016                2
# 17                         Day  6.000000            2016                2
# 27                         Day  6.000000            2016                2
# 58                         Day  6.000000            2016                2
# ...                        ...       ...             ...              ...
# 1516059                    Day  0.476667            2019                8
# 1516060                    Day  0.448056            2019                8
# 1516061                    Day  0.474444            2019                8
# 1516062                    Day  0.489167            2019                8
# 1516063                    Day  0.490278            2019                8
#
#         Start_Time_DAY Start_Time_HOUR End_Time_YEAR End_Time_MONTH  \
# 8                    8        08:15:41          2016              2
# 16                   8        18:11:11          2016              2
# 17                   8        18:11:11          2016              2
# 27                   9        07:18:10          2016              2
# 58                  10        09:06:09          2016              2
# ...                ...             ...           ...            ...
# 1516059             23        18:03:25          2019              8
# 1516060             23        19:11:30          2019              8
# 1516061             23        19:00:21          2019              8
# 1516062             23        19:00:21          2019              8
# 1516063             23        18:52:06          2019              8
#
#         End_Time_DAY End_Time_HOUR
# 8                  8      14:15:41
# 16                 9      00:11:11
# 17                 9      00:11:11
# 27                 9      13:18:10
# 58                10      15:06:09
# ...              ...           ...
# 1516059           23      18:32:01
# 1516060           23      19:38:23
# 1516061           23      19:28:49
# 1516062           23      19:29:42
# 1516063           23      19:21:31
#
# [1133463 rows x 56 columns]

# %%
#SEVERIDAD 1: Numero de accidentes con severidad "1" a lo largo del tiempo segun Weather Condition 
import seaborn as sns
import matplotlib.pyplot as plt
accFiveWC_3v=accFiveWC[['Weather_Condition','Severity','End_Time_MONTH']]
accFiveWC_3v_df1=accFiveWC_3v.loc[accFiveWC_3v["Severity"]==1]
accFiveWC_3v_df2=accFiveWC_3v_df1.groupby(["End_Time_MONTH"], sort=True)['Weather_Condition'].value_counts(ascending=True)
accFiveWC_3v_df2.unstack().plot(kind='bar')
plt.xlabel("Month number", labelpad=14)
plt.title("Severity 1", y=1.02);

# %%
#SEVERIDAD 2: Numero de accidentes con severidad "2" a lo largo del tiempo segun Weather Condition 
import seaborn as sns
import matplotlib.pyplot as plt
accFiveWC_3v=accFiveWC[['Weather_Condition','Severity','End_Time_MONTH']]
accFiveWC_3v_df1=accFiveWC_3v.loc[accFiveWC_3v["Severity"]==2]
accFiveWC_3v_df2=accFiveWC_3v_df1.groupby(["End_Time_MONTH"], sort=True)['Weather_Condition'].value_counts(ascending=True)
accFiveWC_3v_df2.unstack().plot(kind='bar')
plt.xlabel("Month number", labelpad=14)
plt.title("Severity 2", y=1.02);

# %%
#SEVERIDAD 3: Numero de accidentes con severidad "3" a lo largo del tiempo segun Weather Condition 
import seaborn as sns
import matplotlib.pyplot as plt
accFiveWC_3v=accFiveWC[['Weather_Condition','Severity','End_Time_MONTH']]
accFiveWC_3v_df1=accFiveWC_3v.loc[accFiveWC_3v["Severity"]==3]
accFiveWC_3v_df2=accFiveWC_3v_df1.groupby(["End_Time_MONTH"], sort=True)['Weather_Condition'].value_counts(ascending=True)
accFiveWC_3v_df2.unstack().plot(kind='bar')
plt.xlabel("Month number", labelpad=14)
plt.title("Severity 3", y=1.02);

# %%
#SEVERIDAD 4: Numero de accidentes con severidad "4" a lo largo del tiempo segun Weather Condition 
import seaborn as sns
import matplotlib.pyplot as plt
accFiveWC_3v=accFiveWC[['Weather_Condition','Severity','End_Time_MONTH']]
accFiveWC_3v_df1=accFiveWC_3v.loc[accFiveWC_3v["Severity"]==4]
accFiveWC_3v_df2=accFiveWC_3v_df1.groupby(["End_Time_MONTH"], sort=True)['Weather_Condition'].value_counts(ascending=True)
accFiveWC_3v_df2.unstack().plot(kind='bar')
plt.xlabel("Month number", labelpad=14)
plt.title("Severity 4", y=1.02);

# %% [markdown]
# # Caso 2: Wikipedia pages

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\LighthouseLLC\Desktop\Econ\_UNI_Python\data\data\TraficoWeb.csv')
df.columns
# Out:
# Index(['Page', '2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04',
#        '2015-07-05', '2015-07-06', '2015-07-07', '2015-07-08', '2015-07-09',
#        ...
#        '2016-12-22', '2016-12-23', '2016-12-24', '2016-12-25', '2016-12-26',
#        '2016-12-27', '2016-12-28', '2016-12-29', '2016-12-30', '2016-12-31'],
#       dtype='object', length=551)

# %%
import re
dir(re)
output1=re.search("[a-z][a-z].wikipedia.org", df.Page[500])
output1[0][0:2] #dos primeras componentes
# Out:
# 'zh'

# %%
def MakeCountry(p):  #p= page
    output1= re.search("[a-z][a-z].wikipedia.org", p)
    if output1:
        return output1[0][0:2]
    return None

MakeCountry(df.Page[13332])

# %%
df["Country"]=df["Page"].map(MakeCountry)
df.Country.unique()
df.Country.isna().sum()

df.groupby("Country")["Page"].count().sort_values(ascending=False)
# Out:
# Country
# en    24108
# ja    20431
# de    18547
# fr    17802
# zh    17229
# ru    15022
# es    14069
# Name: Page, dtype: int64

# %%
#Cantidad de valores nan para cada observación (fila)

df2=df.set_index('Page')

df3=df2.T
df4=df3.isna().sum()
df5=df3.T
df5['NanS']=pd.DataFrame(df4)
df5
# Out:
#                                                    2015-07-01 2015-07-02  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                    18         11
# 2PM_zh.wikipedia.org_all-access_spider                     11         14
# 3C_zh.wikipedia.org_all-access_spider                       1          0
# 4minute_zh.wikipedia.org_all-access_spider                 35         13
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...        NaN        NaN
# ...                                                       ...        ...
# Underworld_(serie_de_películas)_es.wikipedia.or...        NaN        NaN
# Resident_Evil:_Capítulo_Final_es.wikipedia.org_...        NaN        NaN
# Enamorándome_de_Ramón_es.wikipedia.org_all-acce...        NaN        NaN
# Hasta_el_último_hombre_es.wikipedia.org_all-acc...        NaN        NaN
# Francisco_el_matemático_(serie_de_televisión_de...        NaN        NaN
#
#                                                    2015-07-03 2015-07-04  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                     5         13
# 2PM_zh.wikipedia.org_all-access_spider                     15         18
# 3C_zh.wikipedia.org_all-access_spider                       1          1
# 4minute_zh.wikipedia.org_all-access_spider                 10         94
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...        NaN        NaN
# ...                                                       ...        ...
# Underworld_(serie_de_películas)_es.wikipedia.or...        NaN        NaN
# Resident_Evil:_Capítulo_Final_es.wikipedia.org_...        NaN        NaN
# Enamorándome_de_Ramón_es.wikipedia.org_all-acce...        NaN        NaN
# Hasta_el_último_hombre_es.wikipedia.org_all-acc...        NaN        NaN
# Francisco_el_matemático_(serie_de_televisión_de...        NaN        NaN
#
#                                                    2015-07-05 2015-07-06  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                    14          9
# 2PM_zh.wikipedia.org_all-access_spider                     11         13
# 3C_zh.wikipedia.org_all-access_spider                       0          4
# 4minute_zh.wikipedia.org_all-access_spider                  4         26
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...        NaN        NaN
# ...                                                       ...        ...
# Underworld_(serie_de_películas)_es.wikipedia.or...        NaN        NaN
# Resident_Evil:_Capítulo_Final_es.wikipedia.org_...        NaN        NaN
# Enamorándome_de_Ramón_es.wikipedia.org_all-acce...        NaN        NaN
# Hasta_el_último_hombre_es.wikipedia.org_all-acc...        NaN        NaN
# Francisco_el_matemático_(serie_de_televisión_de...        NaN        NaN
#
#                                                    2015-07-07 2015-07-08  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                     9         22
# 2PM_zh.wikipedia.org_all-access_spider                     22         11
# 3C_zh.wikipedia.org_all-access_spider                       0          3
# 4minute_zh.wikipedia.org_all-access_spider                 14          9
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...        NaN        NaN
# ...                                                       ...        ...
# Underworld_(serie_de_películas)_es.wikipedia.or...        NaN        NaN
# Resident_Evil:_Capítulo_Final_es.wikipedia.org_...        NaN        NaN
# Enamorándome_de_Ramón_es.wikipedia.org_all-acce...        NaN        NaN
# Hasta_el_último_hombre_es.wikipedia.org_all-acc...        NaN        NaN
# Francisco_el_matemático_(serie_de_televisión_de...        NaN        NaN
#
#                                                    2015-07-09 2015-07-10  ...  \
# Page                                                                      ...
# 2NE1_zh.wikipedia.org_all-access_spider                    26         24  ...
# 2PM_zh.wikipedia.org_all-access_spider                     10          4  ...
# 3C_zh.wikipedia.org_all-access_spider                       4          4  ...
# 4minute_zh.wikipedia.org_all-access_spider                 11         16  ...
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...        NaN        NaN  ...
# ...                                                       ...        ...  ...
# Underworld_(serie_de_películas)_es.wikipedia.or...        NaN        NaN  ...
# Resident_Evil:_Capítulo_Final_es.wikipedia.org_...        NaN        NaN  ...
# Enamorándome_de_Ramón_es.wikipedia.org_all-acce...        NaN        NaN  ...
# Hasta_el_último_hombre_es.wikipedia.org_all-acc...        NaN        NaN  ...
# Francisco_el_matemático_(serie_de_televisión_de...        NaN        NaN  ...
#
#                                                    2016-12-24 2016-12-25  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                    15         26
# 2PM_zh.wikipedia.org_all-access_spider                     28         15
# 3C_zh.wikipedia.org_all-access_spider                       1          7
# 4minute_zh.wikipedia.org_all-access_spider                 26         27
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...         25         13
# ...                                                       ...        ...
# Underworld_(serie_de_películas)_es.wikipedia.or...        NaN        NaN
# Resident_Evil:_Capítulo_Final_es.wikipedia.org_...        NaN        NaN
# Enamorándome_de_Ramón_es.wikipedia.org_all-acce...        NaN        NaN
# Hasta_el_último_hombre_es.wikipedia.org_all-acc...        NaN        NaN
# Francisco_el_matemático_(serie_de_televisión_de...        NaN        NaN
#
#                                                    2016-12-26 2016-12-27  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                    14         20
# 2PM_zh.wikipedia.org_all-access_spider                      9         30
# 3C_zh.wikipedia.org_all-access_spider                       4          4
# 4minute_zh.wikipedia.org_all-access_spider                 16         11
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...          3         11
# ...                                                       ...        ...
# Underworld_(serie_de_películas)_es.wikipedia.or...         13         12
# Resident_Evil:_Capítulo_Final_es.wikipedia.org_...        NaN        NaN
# Enamorándome_de_Ramón_es.wikipedia.org_all-acce...        NaN        NaN
# Hasta_el_último_hombre_es.wikipedia.org_all-acc...        NaN        NaN
# Francisco_el_matemático_(serie_de_televisión_de...        NaN        NaN
#
#                                                    2016-12-28 2016-12-29  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                    22         19
# 2PM_zh.wikipedia.org_all-access_spider                     52         45
# 3C_zh.wikipedia.org_all-access_spider                       6          3
# 4minute_zh.wikipedia.org_all-access_spider                 17         19
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...         27         13
# ...                                                       ...        ...
# Underworld_(serie_de_películas)_es.wikipedia.or...         13          3
# Resident_Evil:_Capítulo_Final_es.wikipedia.org_...        NaN        NaN
# Enamorándome_de_Ramón_es.wikipedia.org_all-acce...        NaN        NaN
# Hasta_el_último_hombre_es.wikipedia.org_all-acc...        NaN        NaN
# Francisco_el_matemático_(serie_de_televisión_de...        NaN        NaN
#
#                                                    2016-12-30 2016-12-31  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                    18         20
# 2PM_zh.wikipedia.org_all-access_spider                     26         20
# 3C_zh.wikipedia.org_all-access_spider                       4         17
# 4minute_zh.wikipedia.org_all-access_spider                 10         11
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...         36         10
# ...                                                       ...        ...
# Underworld_(serie_de_películas)_es.wikipedia.or...          5         10
# Resident_Evil:_Capítulo_Final_es.wikipedia.org_...        NaN        NaN
# Enamorándome_de_Ramón_es.wikipedia.org_all-acce...        NaN        NaN
# Hasta_el_último_hombre_es.wikipedia.org_all-acc...        NaN        NaN
# Francisco_el_matemático_(serie_de_televisión_de...        NaN        NaN
#
#                                                    Country NanS
# Page
# 2NE1_zh.wikipedia.org_all-access_spider
wikipedia.org_all-access_all-agents  \
# 2015-07-01                                                599
# 2015-07-02                                                610
# 2015-07-03                                                752
# 2015-07-04                                               2709
# 2015-07-05                                               1754
# ...                                                       ...
# 2016-12-28                                                262
# 2016-12-29                                                248
# 2016-12-30                                                229
# 2016-12-31                                                218
# Country                                                    es
#
# Page       贝尔实验室_zh.wikipedia.org_all-access_spider
# 2015-07-01                                       13
# 2015-07-02                                        7
# 2015-07-03                                       13
# 2015-07-04                                        8
# 2015-07-05                                        7
# ...                                             ...
# 2016-12-28                                        9
# 2016-12-29                                        8
# 2016-12-30                                        6
# 2016-12-31                                       21
# Country                                          zh
#
# [551 rows x 20 columns]

# %%
#Muestra 20 : Grafica
import matplotlib as plot
lines=df8.plot.line()
lines.legend(bbox_to_anchor=(1.0, 1.0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-faa2741cb1d5> in <module>
#       1 #Muestra 20 : Grafica
#       2 import matplotlib as plot
# ----> 3 lines=df8.plot.line()
#       4 lines.legend(bbox_to_anchor=(1.0, 1.0))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#    1015         as coordinates.
#    1016         """
# -> 1017         return self(kind="line", x=x, y=y, **kwargs)
#    1018
#    1019     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     267     def generate(self):
#     268         self._args_adjust()
# --> 269         self._compute_plot_data()
#     270         self._setup_subplots()
#     271         self._make_plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     416         # no non-numeric frames or series allowed
#     417         if is_empty:
# --> 418             raise TypeError("no numeric data to plot")
#     419
#     420         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
# ============================================
# Construccion de modelos para prediccion :
# =============================================
#Paso 1: Obtencion de coeficiente de variacion (CV)y seleccion de pags cuyo CV es menor a 0.7
describe=df8.describe().T
describe['Coef_Variacion']=describe['std']/describe['mean']
describe.sort_values(by='Coef_Variacion', ascending=True)
describe_cv=describe[describe['Coef_Variacion']<0.6]

describe_cv
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'std'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-95d9d2e80567> in <module>
#       4 #Paso 1: Obtencion de coeficiente de variacion (CV)y seleccion de pags cuyo CV es menor a 0.7
#       5 describe=df8.describe().T
# ----> 6 describe['Coef_Variacion']=describe['std']/describe['mean']
#       7 describe.sort_values(by='Coef_Variacion', ascending=True)
#       8 describe_cv=describe[describe['Coef_Variacion']<0.6]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'std'

# %%
describe_cv.index
# Out:
# Index(['John_Travolta_en.wikipedia.org_mobile-web_all-agents',
#        'Donau_de.wikipedia.org_all-access_spider',
#        'Bali_de.wikipedia.org_desktop_all-agents',
#        '東京喰種角色列表_zh.wikipedia.org_desktop_all-agents'],
#       dtype='object', name='Page')

# %%
#Paso 2: Grafica de la seleccion mencionada en el paso 1
import matplotlib as plot
lines=df8[['John_Travolta_en.wikipedia.org_mobile-web_all-agents',
      
       'Bali_de.wikipedia.org_desktop_all-agents']].plot.line()
lines.legend(bbox_to_anchor=(1.0, 1.0))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-57acce9685b4> in <module>
#       1 #Paso 2: Grafica de la seleccion mencionada en el paso 1
#       2 import matplotlib as plot
# ----> 3 lines=df8[['John_Travolta_en.wikipedia.org_mobile-web_all-agents',
#       4
#       5        'Bali_de.wikipedia.org_desktop_all-agents']].plot.line()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['John_Travolta_en.wikipedia.org_mobile-web_all-agents', 'Bali_de.wikipedia.org_desktop_all-agents'], dtype='object', name='Page')] are in the [columns]"

# %%
import matplotlib as plot
lines=df8[[ 'Bali_de.wikipedia.org_desktop_all-agents']].plot.line()
lines.legend(bbox_to_anchor=(1.0, 1.0))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-40edf492336e> in <module>
#       1 import matplotlib as plot
# ----> 2 lines=df8[[ 'Bali_de.wikipedia.org_desktop_all-agents']].plot.line()
#       3 lines.legend(bbox_to_anchor=(1.0, 1.0))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Bali_de.wikipedia.org_desktop_all-agents'], dtype='object', name='Page')] are in the [columns]"

# %%
import matplotlib.pyplot as plt
df8[ 'Bali_de.wikipedia.org_desktop_all-agents']

pd.DataFrame(df8[['Bali_de.wikipedia.org_desktop_all-agents']]).boxplot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bali_de.wikipedia.org_desktop_all-agents'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-dcd15747050a> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 df8[ 'Bali_de.wikipedia.org_desktop_all-agents']
#       3
#       4 pd.DataFrame(df8[['Bali_de.wikipedia.org_desktop_all-agents']]).boxplot()
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Bali_de.wikipedia.org_desktop_all-agents'

# %%
#Paso 2:Eliminacion de outliers
# Outliers: 
#Quantile(0.75)+1.5*IQR
#IQR=quartile_3-quartile_1
df8[ 'Bali_de.wikipedia.org_desktop_all-agents'].T.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bali_de.wikipedia.org_desktop_all-agents'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-005d33fa227a> in <module>
#       3 #Quantile(0.75)+1.5*IQR
#       4 #IQR=quartile_3-quartile_1
# ----> 5 df8[ 'Bali_de.wikipedia.org_desktop_all-agents'].T.describe()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Bali_de.wikipedia.org_desktop_all-agents'

# %%
#Quantile(0.75)+1.5*IQR
#Quantile(0.75)+1.05*(Q3-Q1)
844+1.5*(844- 597.25)
# Out:
# 1214.125

# %%
df9=df8[ 'Bali_de.wikipedia.org_desktop_all-agents'].T
type(df9)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bali_de.wikipedia.org_desktop_all-agents'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-cf85cd4e67fa> in <module>
# ----> 1 df9=df8[ 'Bali_de.wikipedia.org_desktop_all-agents'].T
#       2 type(df9)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Bali_de.wikipedia.org_desktop_all-agents'

# %%
outliers=pd.DataFrame(df8[['Bali_de.wikipedia.org_desktop_all-agents']]>1214.125)
outliers[outliers['Bali_de.wikipedia.org_desktop_all-agents']==True].index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-18bc123ea885> in <module>
# ----> 1 outliers=pd.DataFrame(df8[['Bali_de.wikipedia.org_desktop_all-agents']]>1214.125)
#       2 outliers[outliers['Bali_de.wikipedia.org_desktop_all-agents']==True].index
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Bali_de.wikipedia.org_desktop_all-agents'], dtype='object', name='Page')] are in the [columns]"

# %%
outliers=pd.DataFrame(df8[['Bali_de.wikipedia.org_desktop_all-agents']]>1214.125)
outliers[outliers['Bali_de.wikipedia.org_desktop_all-agents']==True]=None
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-e4bda053ff08> in <module>
# ----> 1 outliers=pd.DataFrame(df8[['Bali_de.wikipedia.org_desktop_all-agents']]>1214.125)
#       2 outliers[outliers['Bali_de.wikipedia.org_desktop_all-agents']==True]=None
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Bali_de.wikipedia.org_desktop_all-agents'], dtype='object', name='Page')] are in the [columns]"

# %%
df9.loc[['2015-07-10', '2015-08-17', '2015-08-18', '2015-08-24', '2016-01-13',
       '2016-01-14', '2016-03-02', '2016-08-12']]=None
df9.loc[['2015-07-10', '2015-08-17', '2015-08-18', '2015-08-24', '2016-01-13',
       '2016-01-14', '2016-03-02', '2016-08-12']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-d8b4256f5af4> in <module>
# ----> 1 df9.loc[['2015-07-10', '2015-08-17', '2015-08-18', '2015-08-24', '2016-01-13',
#       2        '2016-01-14', '2016-03-02', '2016-08-12']]=None
#       3 df9.loc[['2015-07-10', '2015-08-17', '2015-08-18', '2015-08-24', '2016-01-13',
#       4        '2016-01-14', '2016-03-02', '2016-08-12']]
#
# NameError: name 'df9' is not defined

# %%
df9=df9.fillna(method="ffill")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-77187621ae5d> in <module>
# ----> 1 df9=df9.fillna(method="ffill")
#
# NameError: name 'df9' is not defined

# %%
df9[['2015-07-10', '2015-08-17', '2015-08-18', '2015-08-24', '2016-01-13',
       '2016-01-14', '2016-03-02', '2016-08-12']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-f068fe22d49a> in <module>
# ----> 1 df9[['2015-07-10', '2015-08-17', '2015-08-18', '2015-08-24', '2016-01-13',
#       2        '2016-01-14', '2016-03-02', '2016-08-12']]
#
# NameError: name 'df9' is not defined

# %%
df9.plot.line()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-4d091f1b4663> in <module>
# ----> 1 df9.plot.line()
#
# NameError: name 'df9' is not defined

# %%
df9.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-d206806d0adf> in <module>
# ----> 1 df9.index
#
# NameError: name 'df9' is not defined

# %%
df9[['2015-07-01', '2015-07-02']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-1bb9f50d8de6> in <module>
# ----> 1 df9[['2015-07-01', '2015-07-02']]
#
# NameError: name 'df9' is not defined

# %%
df8
# Out:
# Page       鬼平犯科帳_(中村吉右衛門)_ja.wikipedia.org_all-access_spider  \
# 2015-07-01                                                 0
# 2015-07-02                                                 3
# 2015-07-03                                                 8
# 2015-07-04                                                 4
# 2015-07-05                                                 1
# ...                                                      ...
# 2016-12-28                                                39
# 2016-12-29                                                62
# 2016-12-30                                                50
# 2016-12-31                                                43
# Country                                                   ja
#
# Page       School_Days_ja.wikipedia.org_desktop_all-agents  \
# 2015-07-01                                             120
# 2015-07-02                                             117
# 2015-07-03                                             101
# 2015-07-04                                             130
# 2015-07-05                                             116
# ...                                                    ...
# 2016-12-28                                             205
# 2016-12-29                                             155
# 2016-12-30                                             128
# 2016-12-31                                             108
# Country                                                 ja
#
# Page       Proceso_Teller-Ulam_es.wikipedia.org_mobile-web_all-agents  \
# 2015-07-01                                                 52
# 2015-07-02                                                 92
# 2015-07-03                                                 48
# 2015-07-04                                                 35
# 2015-07-05                                                 32
# ...                                                       ...
# 2016-12-28                                                 68
# 2016-12-29                                                 76
# 2016-12-30                                                 97
# 2016-12-31                                                 71
# Country                                                    es
#
# Page       Monica_Lierhaus_de.wikipedia.org_mobile-web_all-agents  \
# 2015-07-01                
wikipedia.org_all-access_all-agents  \
# 2015-07-01                                               544
# 2015-07-02                                               378
# 2015-07-03                                               359
# 2015-07-04                                              1128
# 2015-07-05                                               516
# ...                                                      ...
# 2016-12-28                                            158636
# 2016-12-29                                             11261
# 2016-12-30                                              3078
# 2016-12-31                                              1603
# Country                                                   fr
#
# Page       Джекман,_Хью_ru.wikipedia.org_desktop_all-agents  \
# 2015-07-01                                              715
# 2015-07-02                                              710
# 2015-07-03                                              706
# 2015-07-04                                              793
# 2015-07-05                                              892
# ...                                                     ...
# 2016-12-28                                              739
# 2016-12-29                                              758
# 2016-12-30                                              638
# 2016-12-31                                              529
# Country                                                  ru
#
# Page       Jean-Marc_Généreux_fr.wikipedia.org_all-access_spider  \
# 2015-07-01                                                  0
# 2015-07-02                                                  2
# 2015-07-03                                                  2
# 2015-07-04                                                  4
# 2015-07-05                                                  3
# ...                                                       ...
# 2016-12-28                                                  4
# 2016-12-29                                                  3
# 2016-12-30                                                 14
# 2016-12-31                                                  4
# Country                                                    fr
#
# Page       Anexo:Películas_de_X-Men_es.wikipedia.org_mobile-web_all-agents  \
# 2015-07-01                                                447
# 2015-07-02                                                271
# 2015-07-03                                                395
# 2015-07-04                                                257
# 2015-07-05                                                339
# ...                                                       ...
# 2016-12-28                                               1301
# 2016-12-29                                               3662
# 2016-12-30                                               1695
# 2016-12-31                                               1074
# Country                                                    es
#
# Page       Echte_Wespen_de.wikipedia.org_all-access_spider  \
# 2015-07-01                                               5
# 2015-07-02                                              11
# 2015-07-03                                               5
# 2015-07-04                                              17
# 2015-07-05                                               3
# ...                                                    ...
# 2016-12-28                                              12
# 2016-12-29                                               8
# 2016-12-30                                               6
# 2016-12-31                                               4
# Country                                                 de
#
# Page       2014_Winter_Olympics_en.wikipedia.org_all-access_spider  \
# 2015-07-01                                                 60
# 2015-07-02                                                 38
# 2015-07-03                                                 36
# 2015-07-04                                                 43
# 2015-07-05                                                 32
# ...                                                       ...
# 2016-12-28                                                159
# 2016-12-29                                                 64
# 2016-12-30                                                257
# 2016-12-31                                                 77
# Country                                                    en
#
# Page       Lukas_Podolski_es.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                                599
# 2015-07-02                                                610
# 2015-07-03                                                752
# 2015-07-04                                               2709
# 2015-07-05                                               1754
# ...                                                       ...
# 2016-12-28                                                262
# 2016-12-29                                                248
# 2016-12-30                                                229
# 2016-12-31                                                218
# Country                                                    es
#
# Page       贝尔实验室_zh.wikipedia.org_all-access_spider
# 2015-07-01                                       13
# 2015-07-02                                        7
# 2015-07-03                                       13
# 2015-07-04                                        8
# 2015-07-05                                        7
# ...                                             ...
# 2016-12-28                                        9
# 2016-12-29                                        8
# 2016-12-30                                        6
# 2016-12-31                                       21
# Country                                          zh
#
# [551 rows x 20 columns]

# %%
pd.to_datetime
#Nuevas columnas para End_Time
import datetime as dt
df9["Year"] = df9.index.dt.year
df9["MONTH"] = df9.index.dt.month
df9["DAY"] = df9.index.dt.day
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-453-f89bee7e5cec> in <module>
#       2 #Nuevas columnas para End_Time
#       3 import datetime as dt
# ----> 4 df9["Year"] = df9.index.dt.year
#       5 df9["MONTH"] = df9.index.dt.month
#       6 df9["DAY"] = df9.index.dt.day
#
# AttributeError: 'Index' object has no attribute 'dt'

# %%
df.index=pd.to_datetime(df.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7ce124a90de6> in <module>
# ----> 1 df9
#
# NameError: name 'df9' is not defined
